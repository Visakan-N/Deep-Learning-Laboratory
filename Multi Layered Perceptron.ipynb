# %% [markdown]
# # Multi-Layered Perceptron

# %% [markdown]
# It is a nueral network with more than 3 layers - one input layer, one output layer and more than one hidden layer.

# %% [markdown]
# ### Import the required packages:

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Flatten, Dense, Activation
from tensorflow.keras.models import Sequential

# %% [markdown]
# ### Get the dataset:

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %% [markdown]
# ### Data Preprocessing:

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %% [markdown]
# ### Data Normalization:

# %%
gray_scale = 255
x_train /= gray_scale
x_test /= gray_scale

print("Feature matrix:", x_train.shape)
print("Target matrix:", x_test.shape)
print("Feature matrix:", y_train.shape)
print("Target matrix:", y_test.shape)
# Out:
# Feature matrix: (60000, 28, 28)
# Target matrix: (10000, 28, 28)
# Feature matrix: (60000,)
# Target matrix: (10000,)

# %% [markdown]
# ### Creating the model:

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='sigmoid'),
    Dense(128, activation='sigmoid'),
    Dense(10, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model:

# %%
history = model.fit(x_train, y_train,
          epochs=20,
          batch_size=2000,
          validation_split=0.2)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 39ms/step - loss: 2.0879 - accuracy: 0.4539 - val_loss: 1.7412 - val_accuracy: 0.7444
# Epoch 2/20
# 24/24 [==============================] - 1s 30ms/step - loss: 1.3996 - accuracy: 0.7444 - val_loss: 1.0345 - val_accuracy: 0.8077
# Epoch 3/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.8566 - accuracy: 0.8234 - val_loss: 0.6582 - val_accuracy: 0.8638
# Epoch 4/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.5909 - accuracy: 0.8676 - val_loss: 0.4825 - val_accuracy: 0.8869
# Epoch 5/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.4606 - accuracy: 0.8880 - val_loss: 0.3952 - val_accuracy: 0.9005
# Epoch 6/20
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3909 - accuracy: 0.8997 - val_loss: 0.3466 - val_accuracy: 0.9103
# Epoch 7/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3485 - accuracy: 0.9075 - val_loss: 0.3142 - val_accuracy: 0.9151
# Epoch 8/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3194 - accuracy: 0.9130 - val_loss: 0.2928 - val_accuracy: 0.9194
# Epoch 9/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2970 - accuracy: 0.9180 - val_loss: 0.2731 - val_accuracy: 0.9252
# Epoch 10/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2793 - accuracy: 0.9216 - val_loss: 0.2596 - val_accuracy: 0.9277
# Epoch 11/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2645 - accuracy: 0.9251 - val_loss: 0.2484 - val_accuracy: 0.9293
# Epoch 12/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2511 - accuracy: 0.9288 - val_loss: 0.2372 - val_accuracy: 0.9318
# Epoch 13/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.2392 - accuracy: 0.9319 - val_loss: 0.2268 - val_accuracy: 0.9355
# Epoch 14/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2282 - accuracy: 0.9352 - val_loss: 0.2198 - val_accuracy: 0.9362
# Epoch 15/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2187 - accuracy: 0.9375 - val_loss: 0.2113 - val_accuracy: 0.9403
# Epoch 16/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2095 - accuracy: 0.9399 - val_loss: 0.2032 - val_accuracy: 0.9432
# Epoch 17/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2007 - accuracy: 0.9429 - val_loss: 0.1979 - val_accuracy: 0.9448
# Epoch 18/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.1924 - accuracy: 0.9441 - val_loss: 0.1904 - val_accuracy: 0.9463
# Epoch 19/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1841 - accuracy: 0.9475 - val_loss: 0.1843 - val_accuracy: 0.9478
# Epoch 20/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1766 - accuracy: 0.9496 - val_loss: 0.1801 - val_accuracy: 0.9499

# %% [markdown]
# ### Plotting accuracy and loss:

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend(['Train','Val'])

axs[1].plot(history.history['accuracy'])
axs[1].plot(history.history['val_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend(['Train', 'Val'])

# %% [markdown]
# ### Evaluate the model:

# %%
results = model.evaluate(x_test, y_test, verbose = 0)
print('For multilayer perceptron: test loss, test acc:', results)
# Out:
# For multilayer perceptron: test loss, test acc: [0.27549228072166443, 0.9236000180244446]
